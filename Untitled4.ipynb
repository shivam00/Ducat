# %%
import pandas as pd
import numpy as np
data = pd.read_csv("train1.csv", index_col="Loan_ID")

# %%
data
# Out:
#           Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002    Male      No          0      Graduate            No
# LP001003    Male     Yes          1      Graduate            No
# LP001005    Male     Yes          0      Graduate           Yes
# LP001006    Male     Yes          0  Not Graduate            No
# LP001008    Male      No          0      Graduate            No
# LP001011    Male     Yes          2      Graduate           Yes
# LP001013    Male     Yes          0  Not Graduate            No
# LP001014    Male     Yes         3+      Graduate            No
# LP001018    Male     Yes          2      Graduate            No
# LP001020    Male     Yes          1      Graduate            No
# LP001024    Male     Yes          2      Graduate            No
# LP001027    Male     Yes          2      Graduate           NaN
# LP001028    Male     Yes          2      Graduate            No
# ...

# %%
import math
def num_missing(x):
  return sum(math.isnan(x)())
data.apply(num_missing, axis=1).head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-d526b2de6f65> in <module>
#       2 def num_missing(x):
#       3   return sum(math.isnan(x)())
# ----> 4 data.apply(num_missing, axis=1).head()
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     246
# ...

# %%
from scipy.stats import mode
data['Gender'].mode()
# Out:
# 0    Male
# dtype: object

# %%
data.loc[(data["Gender"]!="Female") & (data["Gender"]!="Male")]
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001050    NaN     Yes          2  Not Graduate            No
# LP001448    NaN     Yes         3+      Graduate            No
# LP001585    NaN     Yes         3+      Graduate            No
# LP001644    NaN     Yes          0      Graduate           Yes
# LP002024    NaN     Yes          0      Graduate            No
# LP002103    NaN     Yes          1      Graduate           Yes
# LP002478    NaN     Yes          0      Graduate           Yes
# LP002501    NaN     Yes          0      Graduate            No
# LP002530    NaN     Yes          2      Graduate            No
# LP002625    NaN      No          0      Graduate            No
# LP002872    NaN     Yes          0      Graduate            No
# LP002925    NaN      No          0      Graduate            No
# LP002933    NaN      No         3+      Graduate           Yes
#
# ...
